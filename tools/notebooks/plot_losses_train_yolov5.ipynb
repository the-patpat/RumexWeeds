# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/pat/gbar_transfer/scratch/yolov5/runs/train/exp4/results.csv')
df
# Out:
#                    epoch        train/box_loss        train/obj_loss  \
# 0                      0              0.093711              0.031723
# 1                      1              0.065198              0.028395
# 2                      2              0.057215              0.025380
# 3                      3              0.051085              0.024684
# 4                      4              0.047405              0.022884
# ..                   ...                   ...                   ...
# 95                    95              0.017315              0.009093
# 96                    96              0.017071              0.009110
# 97                    97              0.016836              0.008891
# 98                    98              0.017148              0.008739
# 99                    99              0.016877              0.008991
#
#           train/cls_loss     metrics/precision        metrics/recall  \
# ...

# %%
df.columns = [x.strip() for x in df.columns]

# %%
df[["train/box_loss", "train/obj_loss"]].plot()
df[["val/box_loss", "val/obj_loss"]].plot()
plt.figure()
df["metrics/mAP_0.5:0.95"].plot()
# Out:
# <AxesSubplot:>
